# %% [markdown]
# <a href="https://colab.research.google.com/github/brandongloria/Skyline-Math-200/blob/main/Python_Notebook_Setup_by_Brandon_Gloria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Research Question # __ : Include question here

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %% [markdown]
# Codebook 1

# %%
#Manage data for variable 1

# %% [markdown]
# ![Screenshot 2023-05-03 at 10.11.33 AM.png](data:image/png;base64,...)

# %%
#Graphs and tables or statistics
df['number_of_siblings']=df['H4WS1']

# %%
df['number_of_siblings'].dtype
# Out:
# dtype('O')

# %%
df['number_of_siblings']= pd.to_numeric(df['number_of_siblings'],errors= 'coerce')
df['number_of_siblings'].dtype
# Out:
# dtype('float64')

# %%
df['number_of_siblings'] = df['number_of_siblings'].loc[df['number_of_siblings'] !=96] 
df['number_of_siblings'] = df['number_of_siblings'].loc[df['number_of_siblings'] !=98]
df['number_of_siblings'].value_counts()
# Out:
# 1.0     1342
# 2.0     1265
# 3.0      813
# 4.0      539
# 5.0      305
# 0.0      242
# 6.0      215
# 7.0      141
# 8.0       84
# 9.0       56
# 10.0      35
# 11.0      20
# 12.0      14
# 13.0       8
# 20.0       8
# 15.0       6
# 17.0       4
# 14.0       4
# 16.0       1
# 19.0       1
# Name: number_of_siblings, dtype: int64

# %%
import seaborn as sns

# %%
sns.histplot(x= 'number_of_siblings', data = df, bins = 15)
# Out:
# <Axes: xlabel='number_of_siblings', ylabel='Count'>

# %%
sns.boxplot(x= 'number_of_siblings', data = df)
# Out:
# <Axes: xlabel='number_of_siblings'>

# %%
sns.histplot( x= 'number_of_siblings', data=df, bins = 15, color ='green', kde= True)
# Out:
# <Axes: xlabel='number_of_siblings', ylabel='Count'>

# %% [markdown]
# Codebook 2:

# %%
#Manage data for variable 2

# %% [markdown]
# ![Screenshot 2023-05-03 at 10.16.50 AM.png](data:image/png;base64,...)

# %%
#Graphs and tables or statistics
df['seven_days_screen']=df['H4DA1']

# %%
df['seven_days_screen'].dtype
# Out:
# dtype('O')

# %%
df['seven_days_screen']= pd.to_numeric(df['seven_days_screen'],errors= 'coerce')
df['seven_days_screen'].dtype
# Out:
# dtype('float64')

# %%
df['seven_days_screen'] = df['seven_days_screen'].loc[df['seven_days_screen'] !=996] 
df['seven_days_screen'] = df['seven_days_screen'].loc[df['seven_days_screen'] !=998]
df['seven_days_screen'].value_counts()
# Out:
# 10.0     562
# 14.0     421
# 20.0     350
# 2.0      332
# 5.0      327
#         ...
# 105.0      1
# 121.0      1
# 98.0       1
# 19.0       1
# 110.0      1
# Name: seven_days_screen, Length: 63, dtype: int64

# %%
sns.histplot(x= 'seven_days_screen', data = df, bins = 15)
# Out:
# <Axes: xlabel='seven_days_screen', ylabel='Count'>

# %%
sns.boxplot(x= 'seven_days_screen', data = df)
# Out:
# <Axes: xlabel='seven_days_screen'>

# %%
sns.histplot( x= 'seven_days_screen', data=df, bins= 15, color ='green', kde= True)
# Out:
# <Axes: xlabel='seven_days_screen', ylabel='Count'>

# %% [markdown]
# ![Screenshot 2023-05-03 at 10.20.33 AM.png](data:image/png;base64,...)

# %%
df['high_school_status']=df['H4ED1']

# %%
df['high_school_status'].dtype
# Out:
# dtype('O')

# %%
df['high_school_status'] = df['H4ED1']
df['high_school_status'] = df['high_school_status'].loc[ df['high_school_status'] !=' ' ]
df['high_school_status'] = df['high_school_status'].loc[ df['high_school_status'] !='6' ]
df['high_school_status'] = df['high_school_status'].loc[ df['high_school_status'] !='8' ]
df['high_school_status'].value_counts()
# Out:
# 1    4352
# 2     418
# 4     326
# 3      17
# Name: high_school_status, dtype: int64

# %%
df['high_school_status'].replace(['1','2','3','4'], ['diploma','diploma','diploma','no diploma'],inplace=True)
df['high_school_status'].value_counts()
# Out:
# diploma       4787
# no diploma     326
# Name: high_school_status, dtype: int64

# %%
df['high_school_status'].value_counts(normalize=True).plot( kind = 'bar')
# Out:
# <Axes: >

# %%
df['high_school_status'].value_counts(normalize=True).plot( kind = 'pie')
# Out:
# <Axes: ylabel='high_school_status'>

# %% [markdown]
# ![Screenshot 2023-05-03 at 10.23.36 AM.png](data:image/png;base64,...)

# %%
df['born_us_citizen']=df['H4OD4']

# %%
df['born_us_citizen'].dtype
# Out:
# dtype('O')

# %%
df['born_us_citizen']=df['H4OD4']
df['born_us_citizen'] = df['born_us_citizen'].loc[ df['born_us_citizen'] !='6' ]
df['born_us_citizen'] = df['born_us_citizen'].loc[ df['born_us_citizen'] !=' ' ]
df['born_us_citizen'].value_counts()
# Out:
# 1    4937
# 0     177
# Name: born_us_citizen, dtype: int64

# %%
df['born_us_citizen'].replace(['0','1'], ['no','yes'],inplace=True)
df['born_us_citizen'].value_counts()
# Out:
# yes    4937
# no      177
# Name: born_us_citizen, dtype: int64

# %%
df['born_us_citizen'].value_counts(normalize=True).plot( kind = 'bar')
# Out:
# <Axes: >

# %%
df['born_us_citizen'].value_counts(normalize=True).plot( kind = 'pie')
# Out:
# <Axes: ylabel='born_us_citizen'>
